# %%
# Matplotlib Inline Charts
# %matplotlib inline

# %%
# Import Dependencies
from citipy import citipy
from datetime import datetime
import gmaps
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import requests
from scipy.stats import linregress
import time

# Import the API keys.
from config import weather_api_key
from config import g_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&lang=en&APPID=" + weather_api_key

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 782

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------\n")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard. (Not used currently. Retained for potential future use.)
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("\n-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
#
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | yinchuan
# Processing Record 6 of Set 1 | puerto escondido
# Processing Record 7 of Set 1 | ancud
# Processing Record 8 of Set 1 | asau
# Processing Record 9 of Set 1 | severo-kurilsk
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | lavrentiya
# Processing Record 12 of Set 1 | upernavik
# Processing Record 13 of Set 1 | longyearbyen
# Processing Record 14 of Set 1 | cholet
# Processing Record 15 of Set 1 | pasco
# Processing Record 16 of Set 1 | thompson
# Processing Record 17 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 1 | borovsk
# Processing Record 19 of Set 1 | kaitangata
# Processing Record 20 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 1 | morrope
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | daru
# Processing Record 24 of Set 1 | ucluelet
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | severo-yeniseyskiy
# Processing Record 27 of Set 1 | grand gaube
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | maniitsoq
# Processing Record 31 of Set 1 | kyaukse
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | chokurdakh
# Processing Record 35 of Set 1 | maragogi
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | mwinilunga
# Processing Record 38 of Set 1 | carnarvon
# Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 1 | muros
# Processing Record 41 of Set 1 | baringo
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | nanortalik
# Processing Record 44 of Set 1 | wajir
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | constitucion
# Processing Record 48 of Set 1 | garden city
# Processing Record 49 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 1 | alexandria
# Processing Record 1 of Set 2 | airai
# Processing Record 2 of Set 2 | tommot
# Processing Record 3 of Set 2 | sembabule
# Processing Record 4 of Set 2 | fort nelson
# Processing Record 5 of Set 2 | baghdad
# Processing Record 6 of Set 2 | olenegorsk
# Processing Record 7 of Set 2 | ostrovnoy
# Processing Record 8 of Set 2 | huarmey
# Processing Record 9 of Set 2 | wadi maliz
# Processing Record 10 of Set 2 | los llanos de aridane
# Processing Record 11 of Set 2 | rikitea
# Processing Record 12 of Set 2 | sao joao da barra
# Processing Record 13 of Set 2 | taunggyi
# Processing Record 14 of Set 2 | masuguru
# Processing Record 15 of Set 2 | cuamba
# Processing Record 16 of Set 2 | meulaboh
# Processing Record 17 of Set 2 | uroteppa
# City not found. Skipping...
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | fontem
# Processing Record 20 of Set 2 | atar
# Processing Record 21 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | san ramon
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | kieta
# Processing Record 29 of Set 2 | banda aceh
# Processing Record 30 of Set 2 | nome
# Processing Record 31 of Set 2 | cervo
# Processing Record 32 of Set 2 | baykit
# Processing Record 33 of Set 2 | mecca
# Processing Record 34 of Set 2 | cherskiy
# Processing Record 35 of Set 2 | narsaq
# Processing Record 36 of Set 2 | biak
# Processing Record 37 of Set 2 | betafo
# Processing Record 38 of Set 2 | tiksi
# Processing Record 39 of Set 2 | rajanpur
# Processing Record 40 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 2 | tura
# Processing Record 42 of Set 2 | springbok
# Processing Record 43 of Set 2 | tessalit
# Processing Record 44 of Set 2 | ouadda
# Processing Record 45 of Set 2 | namatanai
# Processing Record 46 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 2 | alihe
# Processing Record 48 of Set 2 | murray bridge
# Processing Record 49 of Set 2 | hambantota
# Processing Record 50 of Set 2 | bengkulu
# Processing Record 1 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 3 | barrow
# Processing Record 3 of Set 3 | illapel
# Processing Record 4 of Set 3 | caorle
# Processing Record 5 of Set 3 | codrington
# Processing Record 6 of Set 3 | saskylakh
# Processing Record 7 of Set 3 | paamiut
# Processing Record 8 of Set 3 | torbay
# Processing Record 9 of Set 3 | saint-philippe
# Processing Record 10 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 3 | chuy
# Processing Record 13 of Set 3 | esperance
# Processing Record 14 of Set 3 | yarada
# Processing Record 15 of Set 3 | petatlan
# Processing Record 16 of Set 3 | hithadhoo
# Processing Record 17 of Set 3 | liuhe
# Processing Record 18 of Set 3 | vanimo
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 20 of Set 3 | yar-sale
# Processing Record 21 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 3 | kralendijk
# Processing Record 23 of Set 3 | flin flon
# Processing Record 24 of Set 3 | east london
# Processing Record 25 of Set 3 | atambua
# Processing Record 26 of Set 3 | geraldton
# Processing Record 27 of Set 3 | bol
# Processing Record 28 of Set 3 | leshukonskoye
# Processing Record 29 of Set 3 | buchanan
# Processing Record 30 of Set 3 | islamkot
# Processing Record 31 of Set 3 | ahipara
# Processing Record 32 of Set 3 | mehamn
# Processing Record 33 of Set 3 | zeya
# Processing Record 34 of Set 3 | yellowknife
# Processing Record 35 of Set 3 | sisimiut
# Processing Record 36 of Set 3 | faya
# Processing Record 37 of Set 3 | kautokeino
# Processing Record 38 of Set 3 | sorkjosen
# Processing Record 39 of Set 3 | kawalu
# Processing Record 40 of Set 3 | hobart
# Processing Record 41 of Set 3 | mar del plata
# Processing Record 42 of Set 3 | northam
# Processing Record 43 of Set 3 | manaure
# Processing Record 44 of Set 3 | lebu
# Processing Record 45 of Set 3 | half moon bay
# Processing Record 46 of Set 3 | oranjestad
# Processing Record 47 of Set 3 | kanker
# Processing Record 48 of Set 3 | zhigalovo
# Processing Record 49 of Set 3 | prince george
# Processing Record 50 of Set 3 | kalmar
# Processing Record 1 of Set 4 | bintulu
# Processing Record 2 of Set 4 | naze
# Processing Record 3 of Set 4 | torrington
# Processing Record 4 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 4 | cabo san lucas
# Processing Record 6 of Set 4 | sao filipe
# Processing Record 7 of Set 4 | kagoro
# Processing Record 8 of Set 4 | grindavik
# Processing Record 9 of Set 4 | saint-francois
# Processing Record 10 of Set 4 | hachinohe
# Processing Record 11 of Set 4 | khatanga
# Processing Record 12 of Set 4 | kruisfontein
# Processing Record 13 of Set 4 | mokrous
# Processing Record 14 of Set 4 | vicuna
# Processing Record 15 of Set 4 | hami
# Processing Record 16 of Set 4 | jasper
# Processing Record 17 of Set 4 | bull savanna
# Processing Record 18 of Set 4 | derzhavinsk
# Processing Record 19 of Set 4 | katherine
# Processing Record 20 of Set 4 | marzuq
# Processing Record 21 of Set 4 | lahat
# Processing Record 22 of Set 4 | kenai
# Processing Record 23 of Set 4 | port alfred
# Processing Record 24 of Set 4 | new norfolk
# Processing Record 25 of Set 4 | prince rupert
# Processing Record 26 of Set 4 | leningradskiy
# Processing Record 27 of Set 4 | victoria
# Processing Record 28 of Set 4 | massaguet
# Processing Record 29 of Set 4 | nishihara
# Processing Record 30 of Set 4 | marystown
# Processing Record 31 of Set 4 | ilhabela
# Processing Record 32 of Set 4 | carutapera
# Processing Record 33 of Set 4 | bandrele
# Processing Record 34 of Set 4 | faanui
# Processing Record 35 of Set 4 | castro
# Processing Record 36 of Set 4 | nyurba
# Processing Record 37 of Set 4 | conceicao do mato dentro
# Processing Record 38 of Set 4 | tuatapere
# Processing Record 39 of Set 4 | saint george
# Processing Record 40 of Set 4 | avarua
# Processing Record 41 of Set 4 | isangel
# Processing Record 42 of Set 4 | bambous virieux
# Processing Record 43 of Set 4 | bereda
# Processing Record 44 of Set 4 | bethel
# Processing Record 45 of Set 4 | okhotsk
# Processing Record 46 of Set 4 | gamba
# Processing Record 47 of Set 4 | bathsheba
# Processing Record 48 of Set 4 | gazli
# Processing Record 49 of Set 4 | lagoa
# Processing Record 50 of Set 4 | san quintin
# Processing Record 1 of Set 5 | oreanda
# City not found. Skipping...
# Processing Record 2 of Set 5 | linhares
# Processing Record 3 of Set 5 | sitka
# Processing Record 4 of Set 5 | dohar
# Processing Record 5 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 6 of Set 5 | celestun
# Processing Record 7 of Set 5 | markova
# Processing Record 8 of Set 5 | dire
# Processing Record 9 of Set 5 | akdepe
# Processing Record 10 of Set 5 | cidreira
# Processing Record 11 of Set 5 | tsienyane
# City not found. Skipping...
# Processing Record 12 of Set 5 | amarkantak
# Processing Record 13 of Set 5 | angoche
# Processing Record 14 of Set 5 | fortuna
# Processing Record 15 of Set 5 | haines junction
# Processing Record 16 of Set 5 | khor
# Processing Record 17 of Set 5 | pevek
# Processing Record 18 of Set 5 | monrovia
# Processing Record 19 of Set 5 | lahaina
# Processing Record 20 of Set 5 | dikson
# Processing Record 21 of Set 5 | mount gambier
# Processing Record 22 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 5 | saldanha
# Processing Record 24 of Set 5 | birecik
# Processing Record 25 of Set 5 | padang
# Processing Record 26 of Set 5 | zaykovo
# Processing Record 27 of Set 5 | dulce nombre de culmi
# Processing Record 28 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 29 of Set 5 | porangatu
# Processing Record 30 of Set 5 | le port
# Processing Record 31 of Set 5 | katsuura
# Processing Record 32 of Set 5 | shingu
# Processing Record 33 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 34 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 5 | isabela
# Processing Record 36 of Set 5 | pemberton
# Processing Record 37 of Set 5 | pangnirtung
# Processing Record 38 of Set 5 | namibe
# Processing Record 39 of Set 5 | acajutla
# Processing Record 40 of Set 5 | makakilo city
# Processing Record 41 of Set 5 | venezuela
# Processing Record 42 of Set 5 | zolotinka
# City not found. Skipping...
# Processing Record 43 of Set 5 | rezekne
# Processing Record 44 of Set 5 | dingle
# Processing Record 45 of Set 5 | brae
# Processing Record 46 of Set 5 | moose factory
# Processing Record 47 of Set 5 | mana
# Processing Record 48 of Set 5 | shache
# Processing Record 49 of Set 5 | jalu
# Processing Record 50 of Set 5 | danshui
# Processing Record 1 of Set 6 | srednekolymsk
# Processing Record 2 of Set 6 | vila velha
# Processing Record 3 of Set 6 | luderitz
# Processing Record 4 of Set 6 | nara
# Processing Record 5 of Set 6 | tadine
# Processing Record 6 of Set 6 | kahului
# Processing Record 7 of Set 6 | opelousas
# Processing Record 8 of Set 6 | sur
# Processing Record 9 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 6 | simbahan
# Processing Record 11 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 6 | iqaluit
# Processing Record 13 of Set 6 | umm kaddadah
# Processing Record 14 of Set 6 | porbandar
# Processing Record 15 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 16 of Set 6 | ascension
# Processing Record 17 of Set 6 | coihaique
# Processing Record 18 of Set 6 | hasaki
# Processing Record 19 of Set 6 | lampazos de naranjo
# Processing Record 20 of Set 6 | georgetown
# Processing Record 21 of Set 6 | kichera
# Processing Record 22 of Set 6 | belaya gora
# Processing Record 23 of Set 6 | kjollefjord
# Processing Record 24 of Set 6 | marrakesh
# Processing Record 25 of Set 6 | adrar
# Processing Record 26 of Set 6 | mionica
# Processing Record 27 of Set 6 | tan an
# Processing Record 28 of Set 6 | zhigansk
# Processing Record 29 of Set 6 | anadyr
# Processing Record 30 of Set 6 | mahebourg
# Processing Record 31 of Set 6 | provideniya
# Processing Record 32 of Set 6 | san ignacio
# Processing Record 33 of Set 6 | alofi
# Processing Record 34 of Set 6 | port-gentil
# Processing Record 35 of Set 6 | fairbanks
# Processing Record 36 of Set 6 | mmabatho
# Processing Record 37 of Set 6 | lata
# Processing Record 38 of Set 6 | zyryanka
# Processing Record 39 of Set 6 | kushima
# Processing Record 40 of Set 6 | vardo
# Processing Record 41 of Set 6 | auki
# Processing Record 42 of Set 6 | scarborough
# Processing Record 43 of Set 6 | labuhan
# Processing Record 44 of Set 6 | caravelas
# Processing Record 45 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 6 | chimbote
# Processing Record 47 of Set 6 | lynn haven
# Processing Record 48 of Set 6 | betsiamites
# Processing Record 49 of Set 6 | kavaratti
# Processing Record 50 of Set 6 | golspie
# Processing Record 1 of Set 7 | chipinge
# Processing Record 2 of Set 7 | cooma
# Processing Record 3 of Set 7 | tarancon
# Processing Record 4 of Set 7 | vila franca do campo
# Processing Record 5 of Set 7 | norman wells
# Processing Record 6 of Set 7 | felidhoo
# City not found. Skipping...
# Processing Record 7 of Set 7 | udachnyy
# Processing Record 8 of Set 7 | kwinana
# Processing Record 9 of Set 7 | nybro
# Processing Record 10 of Set 7 | washington
# Processing Record 11 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 7 | hobyo
# Processing Record 13 of Set 7 | mutsu
# Processing Record 14 of Set 7 | santa maria
# Processing Record 15 of Set 7 | nikolskoye
# Processing Record 16 of Set 7 | portland
# Processing Record 17 of Set 7 | port hedland
# Processing Record 18 of Set 7 | polson
# Processing Record 19 of Set 7 | praia da vitoria
# Processing Record 20 of Set 7 | yerbogachen
# Processing Record 21 of Set 7 | lazaro cardenas
# Processing Record 22 of Set 7 | rockport
# Processing Record 23 of Set 7 | jiwani
# Processing Record 24 of Set 7 | dakar
# Processing Record 25 of Set 7 | verkhnyaya khava
# Processing Record 26 of Set 7 | dibaya
# City not found. Skipping...
# Processing Record 27 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 7 | kerema
# Processing Record 29 of Set 7 | flinders
# Processing Record 30 of Set 7 | saint-joseph
# Processing Record 31 of Set 7 | jiaozuo
# Processing Record 32 of Set 7 | salalah
# Processing Record 33 of Set 7 | acapulco
# Processing Record 34 of Set 7 | grants
# Processing Record 35 of Set 7 | taganak
# Processing Record 36 of Set 7 | byron bay
# Processing Record 37 of Set 7 | kupang
# Processing Record 38 of Set 7 | soyo
# Processing Record 39 of Set 7 | ishigaki
# Processing Record 40 of Set 7 | dickinson
# Processing Record 41 of Set 7 | vyazemskiy
# Processing Record 42 of Set 7 | samarai
# Processing Record 43 of Set 7 | almaznyy
# Processing Record 44 of Set 7 | khorixas
# Processing Record 45 of Set 7 | pisco
# Processing Record 46 of Set 7 | severodvinsk
# Processing Record 47 of Set 7 | malinyi
# Processing Record 48 of Set 7 | nyagan
# Processing Record 49 of Set 7 | puerto leguizamo
# Processing Record 50 of Set 7 | peniche
# Processing Record 1 of Set 8 | porto santo
# Processing Record 2 of Set 8 | dunedin
# Processing Record 3 of Set 8 | vostok
# Processing Record 4 of Set 8 | arlit
# Processing Record 5 of Set 8 | sao miguel do araguaia
# Processing Record 6 of Set 8 | nuuk
# Processing Record 7 of Set 8 | mercedes
# Processing Record 8 of Set 8 | san nicolas
# Processing Record 9 of Set 8 | caucaia
# Processing Record 10 of Set 8 | wladyslawowo
# Processing Record 11 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 8 | langsa
# Processing Record 13 of Set 8 | progreso
# Processing Record 14 of Set 8 | hazorasp
# Processing Record 15 of Set 8 | agadez
# Processing Record 16 of Set 8 | marand
# Processing Record 17 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 8 | arcata
# Processing Record 19 of Set 8 | tasiilaq
# Processing Record 20 of Set 8 | haysville
# Processing Record 21 of Set 8 | la tuque
# Processing Record 22 of Set 8 | evensk
# Processing Record 23 of Set 8 | kenora
# Processing Record 24 of Set 8 | la ronge
# Processing Record 25 of Set 8 | raton
# Processing Record 26 of Set 8 | mao
# Processing Record 27 of Set 8 | otradnoye
# Processing Record 28 of Set 8 | fuerte
# Processing Record 29 of Set 8 | kilindoni
# Processing Record 30 of Set 8 | san cristobal
# Processing Record 31 of Set 8 | teya
# Processing Record 32 of Set 8 | eston
# Processing Record 33 of Set 8 | davila
# Processing Record 34 of Set 8 | ixtapa
# Processing Record 35 of Set 8 | panaba
# Processing Record 36 of Set 8 | albanel
# Processing Record 37 of Set 8 | mamou
# Processing Record 38 of Set 8 | mandsaur
# Processing Record 39 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 8 | sembe
# Processing Record 41 of Set 8 | rochester
# Processing Record 42 of Set 8 | omaha
# Processing Record 43 of Set 8 | russell
# Processing Record 44 of Set 8 | mweka
# Processing Record 45 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 8 | igunga
# Processing Record 47 of Set 8 | lucapa
# Processing Record 48 of Set 8 | bady bassitt
# Processing Record 49 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 50 of Set 8 | trairi
# Processing Record 1 of Set 9 | kuching
# Processing Record 2 of Set 9 | pangody
# Processing Record 3 of Set 9 | qaanaaq
# Processing Record 4 of Set 9 | port lincoln
# Processing Record 5 of Set 9 | arman
# Processing Record 6 of Set 9 | kudahuvadhoo
# Processing Record 7 of Set 9 | burnie
# Processing Record 8 of Set 9 | kazachinskoye
# Processing Record 9 of Set 9 | roald
# Processing Record 10 of Set 9 | estelle
# Processing Record 11 of Set 9 | waddan
# Processing Record 12 of Set 9 | dharchula
# Processing Record 13 of Set 9 | villa bruzual
# Processing Record 14 of Set 9 | lumberton
# Processing Record 15 of Set 9 | barranca
# Processing Record 16 of Set 9 | namie
# Processing Record 17 of Set 9 | solnechnyy
# Processing Record 18 of Set 9 | sanchor
# Processing Record 19 of Set 9 | sinnamary
# Processing Record 20 of Set 9 | quelimane
# Processing Record 21 of Set 9 | valley
# Processing Record 22 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 23 of Set 9 | cayenne
# Processing Record 24 of Set 9 | kasongo-lunda
# Processing Record 25 of Set 9 | bayan
# Processing Record 26 of Set 9 | vilhena
# Processing Record 27 of Set 9 | hualmay
# Processing Record 28 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 9 | obluche
# City not found. Skipping...
# Processing Record 30 of Set 9 | helong
# Processing Record 31 of Set 9 | hamilton
# Processing Record 32 of Set 9 | erenhot
# Processing Record 33 of Set 9 | camacari
# Processing Record 34 of Set 9 | berlevag
# Processing Record 35 of Set 9 | port said
# Processing Record 36 of Set 9 | guerrero negro
# Processing Record 37 of Set 9 | rocha
# Processing Record 38 of Set 9 | henties bay
# Processing Record 39 of Set 9 | gigmoto
# Processing Record 40 of Set 9 | imbituba
# Processing Record 41 of Set 9 | vidim
# Processing Record 42 of Set 9 | koslan
# Processing Record 43 of Set 9 | lujiang
# Processing Record 44 of Set 9 | comodoro rivadavia
# Processing Record 45 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 9 | palmer
# Processing Record 47 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 48 of Set 9 | aswan
# Processing Record 49 of Set 9 | antalaha
# Processing Record 50 of Set 9 | agdam
# Processing Record 1 of Set 10 | ribeira grande
# Processing Record 2 of Set 10 | lethem
# Processing Record 3 of Set 10 | vestmannaeyjar
# Processing Record 4 of Set 10 | tautira
# Processing Record 5 of Set 10 | coquimbo
# Processing Record 6 of Set 10 | sebinkarahisar
# Processing Record 7 of Set 10 | madimba
# Processing Record 8 of Set 10 | ducheng
# Processing Record 9 of Set 10 | vilyuysk
# Processing Record 10 of Set 10 | saint-ambroise
# Processing Record 11 of Set 10 | ko samui
# Processing Record 12 of Set 10 | komsomolskiy
# Processing Record 13 of Set 10 | mumford
# Processing Record 14 of Set 10 | gushikawa
# Processing Record 15 of Set 10 | axim
# Processing Record 16 of Set 10 | chakradharpur
# Processing Record 17 of Set 10 | broken hill
# Processing Record 18 of Set 10 | tabory
# Processing Record 19 of Set 10 | aporawan
# City not found. Skipping...
# Processing Record 20 of Set 10 | labrea
# Processing Record 21 of Set 10 | viedma
# Processing Record 22 of Set 10 | nalut
# Processing Record 23 of Set 10 | broome
# Processing Record 24 of Set 10 | menongue
# Processing Record 25 of Set 10 | zyryanovsk
# Processing Record 26 of Set 10 | college
# Processing Record 27 of Set 10 | kamina
# Processing Record 28 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 10 | oranjemund
# Processing Record 30 of Set 10 | redmond
# Processing Record 31 of Set 10 | mgachi
# Processing Record 32 of Set 10 | ambilobe
# Processing Record 33 of Set 10 | granadilla de abona
# Processing Record 34 of Set 10 | port hardy
# Processing Record 35 of Set 10 | iisalmi
# Processing Record 36 of Set 10 | san patricio
# Processing Record 37 of Set 10 | yenagoa
# Processing Record 38 of Set 10 | ballitoville
# Processing Record 39 of Set 10 | shiloh
# Processing Record 40 of Set 10 | liseleje
# Processing Record 41 of Set 10 | yeppoon
# Processing Record 42 of Set 10 | chara
# Processing Record 43 of Set 10 | hirara
# Processing Record 44 of Set 10 | rio grande
# Processing Record 45 of Set 10 | alta floresta
# Processing Record 46 of Set 10 | turtkul
# City not found. Skipping...
# Processing Record 47 of Set 10 | barabai
# Processing Record 48 of Set 10 | taoudenni
# Processing Record 49 of Set 10 | marsa matruh
# Processing Record 50 of Set 10 | rantauprapat
# Processing Record 1 of Set 11 | jiangyou
# Processing Record 2 of Set 11 | tuy hoa
# Processing Record 3 of Set 11 | naifaru
# Processing Record 4 of Set 11 | elizabeth city
# Processing Record 5 of Set 11 | dhidhdhoo
# Processing Record 6 of Set 11 | warrnambool
# Processing Record 7 of Set 11 | zhanaozen
# Processing Record 8 of Set 11 | vreed en hoop
# City not found. Skipping...
# Processing Record 9 of Set 11 | cedar city
# Processing Record 10 of Set 11 | kamaishi
# Processing Record 11 of Set 11 | saint marys
# Processing Record 12 of Set 11 | gus-zheleznyy
# Processing Record 13 of Set 11 | uglovskoye
# Processing Record 14 of Set 11 | yabrud
# Processing Record 15 of Set 11 | camacha
# Processing Record 16 of Set 11 | kavieng
# Processing Record 17 of Set 11 | svetlyy
# Processing Record 18 of Set 11 | america dourada
# Processing Record 19 of Set 11 | tocopilla
# Processing Record 20 of Set 11 | kharovsk
# Processing Record 21 of Set 11 | kodinsk
# Processing Record 22 of Set 11 | el alto
# Processing Record 23 of Set 11 | amahai
# Processing Record 24 of Set 11 | santa rosa
# Processing Record 25 of Set 11 | tahe
# Processing Record 26 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 11 | whitehorse
# Processing Record 28 of Set 11 | weyburn
# Processing Record 29 of Set 11 | boa vista
# Processing Record 30 of Set 11 | champerico
# Processing Record 31 of Set 11 | safford
# Processing Record 32 of Set 11 | buala
# Processing Record 33 of Set 11 | ginda
# Processing Record 34 of Set 11 | tateyama
# Processing Record 35 of Set 11 | gao
# Processing Record 36 of Set 11 | nabire
# Processing Record 37 of Set 11 | kalmunai
# Processing Record 38 of Set 11 | okahandja
# Processing Record 39 of Set 11 | loanda
# Processing Record 40 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 41 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 11 | kabinda
# Processing Record 43 of Set 11 | boueni
# Processing Record 44 of Set 11 | san carlos de bariloche
# Processing Record 45 of Set 11 | bonfim
# Processing Record 46 of Set 11 | yakeshi
# Processing Record 47 of Set 11 | sai buri
# Processing Record 48 of Set 11 | lasa
# Processing Record 49 of Set 11 | praxedis guerrero
# Processing Record 50 of Set 11 | lucea
# Processing Record 1 of Set 12 | gobabis
# Processing Record 2 of Set 12 | bud
# Processing Record 3 of Set 12 | bartica
# Processing Record 4 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 12 | saint-pierre
# Processing Record 6 of Set 12 | posse
# Processing Record 7 of Set 12 | eureka
# Processing Record 8 of Set 12 | cusco
# Processing Record 9 of Set 12 | kyren
# Processing Record 10 of Set 12 | alzamay
# Processing Record 11 of Set 12 | guachucal
# Processing Record 12 of Set 12 | bani
# Processing Record 13 of Set 12 | orlik
# Processing Record 14 of Set 12 | klaksvik
# Processing Record 15 of Set 12 | sao joao de pirabas
# Processing Record 16 of Set 12 | kampot
# Processing Record 17 of Set 12 | ipixuna
# Processing Record 18 of Set 12 | teluknaga
# Processing Record 19 of Set 12 | port hueneme
# Processing Record 20 of Set 12 | adendorf
# Processing Record 21 of Set 12 | shimoda
# Processing Record 22 of Set 12 | yumen
# Processing Record 23 of Set 12 | atherton
# Processing Record 24 of Set 12 | boca do acre
# Processing Record 25 of Set 12 | poronaysk
# Processing Record 26 of Set 12 | sarangani
# Processing Record 27 of Set 12 | nouadhibou
# Processing Record 28 of Set 12 | banbury
# Processing Record 29 of Set 12 | nambucca heads
# Processing Record 30 of Set 12 | bambanglipuro
# Processing Record 31 of Set 12 | bosanska krupa
# Processing Record 32 of Set 12 | tolaga bay
# Processing Record 33 of Set 12 | scordia
# Processing Record 34 of Set 12 | odienne
# Processing Record 35 of Set 12 | pacific grove
# Processing Record 36 of Set 12 | ilovka
# Processing Record 37 of Set 12 | nouakchott
# Processing Record 38 of Set 12 | nemuro
# Processing Record 39 of Set 12 | howard springs
# Processing Record 40 of Set 12 | najran
# Processing Record 41 of Set 12 | jibuti
# Processing Record 42 of Set 12 | bokoro
# Processing Record 43 of Set 12 | mayor pablo lagerenza
# Processing Record 44 of Set 12 | abengourou
# Processing Record 45 of Set 12 | barra patuca
# Processing Record 46 of Set 12 | kostino
# Processing Record 47 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 48 of Set 12 | tilichiki
# Processing Record 49 of Set 12 | tazovskiy
# Processing Record 50 of Set 12 | valdosta
# Processing Record 1 of Set 13 | dudinka
# Processing Record 2 of Set 13 | taksimo
# Processing Record 3 of Set 13 | tibati
# Processing Record 4 of Set 13 | ratnagiri
# Processing Record 5 of Set 13 | diamantina
# Processing Record 6 of Set 13 | aleksin
# Processing Record 7 of Set 13 | cap malheureux
# Processing Record 8 of Set 13 | san buenaventura
# Processing Record 9 of Set 13 | santiago del estero
# Processing Record 10 of Set 13 | port hawkesbury
# Processing Record 11 of Set 13 | halifax
# Processing Record 12 of Set 13 | hofn
# Processing Record 13 of Set 13 | mount isa
# Processing Record 14 of Set 13 | mende
# Processing Record 15 of Set 13 | bogatyr
# Processing Record 16 of Set 13 | lujan
# Processing Record 17 of Set 13 | chontalpa
# Processing Record 18 of Set 13 | dicabisagan
# Processing Record 19 of Set 13 | weligama
# Processing Record 20 of Set 13 | guaruja
# Processing Record 21 of Set 13 | obzor
# Processing Record 22 of Set 13 | mumbwa
# Processing Record 23 of Set 13 | lompoc
# Processing Record 24 of Set 13 | maceio
# Processing Record 25 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 13 | atbasar
# Processing Record 27 of Set 13 | saint combs
# City not found. Skipping...
# Processing Record 28 of Set 13 | laguna
# Processing Record 29 of Set 13 | erzin
# Processing Record 30 of Set 13 | valparaiso
# Processing Record 31 of Set 13 | damghan
# Processing Record 32 of Set 13 | ponta do sol
# Processing Record 33 of Set 13 | galle
# Processing Record 34 of Set 13 | zverinogolovskoye
# Processing Record 35 of Set 13 | casino
# Processing Record 36 of Set 13 | rehoboth
# Processing Record 37 of Set 13 | rabo de peixe
# Processing Record 38 of Set 13 | stanislav
# Processing Record 39 of Set 13 | vallenar
# Processing Record 40 of Set 13 | beringovskiy
# Processing Record 41 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 13 | kirakira
# Processing Record 43 of Set 13 | nakusp
# Processing Record 44 of Set 13 | tavda
# Processing Record 45 of Set 13 | portree
# Processing Record 46 of Set 13 | alice springs
# Processing Record 47 of Set 13 | souillac
# Processing Record 48 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 13 | ballina
# Processing Record 50 of Set 13 | ketchikan
# Processing Record 1 of Set 14 | bodden town
# Processing Record 2 of Set 14 | hemsedal
# Processing Record 3 of Set 14 | talnakh
# Processing Record 4 of Set 14 | puerto ayacucho
# Processing Record 5 of Set 14 | ponta delgada
# Processing Record 6 of Set 14 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 7 of Set 14 | bonavista
# Processing Record 8 of Set 14 | clyde river
# Processing Record 9 of Set 14 | husavik
# Processing Record 10 of Set 14 | sinop
# Processing Record 11 of Set 14 | bredy
# Processing Record 12 of Set 14 | yafran
# Processing Record 13 of Set 14 | karachi
# Processing Record 14 of Set 14 | plettenberg bay
# Processing Record 15 of Set 14 | maumere
# Processing Record 16 of Set 14 | male
# Processing Record 17 of Set 14 | boralday
# Processing Record 18 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 14 | miri
# Processing Record 20 of Set 14 | guanare
# Processing Record 21 of Set 14 | tra vinh
# Processing Record 22 of Set 14 | cascais
# Processing Record 23 of Set 14 | berdigestyakh
# Processing Record 24 of Set 14 | ugoofaaru
# Processing Record 25 of Set 14 | fare
# Processing Record 26 of Set 14 | tungkang
# City not found. Skipping...
# Processing Record 27 of Set 14 | bollnas
# Processing Record 28 of Set 14 | rundu
# Processing Record 29 of Set 14 | tabou
# Processing Record 30 of Set 14 | ponoka
# Processing Record 31 of Set 14 | yangambi
# Processing Record 32 of Set 14 | abha
# Processing Record 33 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 34 of Set 14 | iberia
# Processing Record 35 of Set 14 | amancio
# City not found. Skipping...
# Processing Record 36 of Set 14 | aguimes
# Processing Record 37 of Set 14 | marsh harbour
# Processing Record 38 of Set 14 | dalbandin
# Processing Record 39 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 40 of Set 14 | biltine
# Processing Record 41 of Set 14 | betong
# Processing Record 42 of Set 14 | pagudpud
# Processing Record 43 of Set 14 | troitskoye
# Processing Record 44 of Set 14 | chapleau
# Processing Record 45 of Set 14 | bairiki
# Processing Record 46 of Set 14 | moses lake
# Processing Record 47 of Set 14 | tucuman
# Processing Record 48 of Set 14 | sterling
# Processing Record 49 of Set 14 | urucara
# Processing Record 50 of Set 14 | gilbues
# Processing Record 1 of Set 15 | bernal
# Processing Record 2 of Set 15 | chokwe
# Processing Record 3 of Set 15 | abnub
# Processing Record 4 of Set 15 | itoman
# Processing Record 5 of Set 15 | sambava
# Processing Record 6 of Set 15 | presidencia roque saenz pena
# Processing Record 7 of Set 15 | saint-augustin
# Processing Record 8 of Set 15 | sakakah
# Processing Record 9 of Set 15 | sorong
# Processing Record 10 of Set 15 | spasskoye
# Processing Record 11 of Set 15 | ocampo
# Processing Record 12 of Set 15 | yulara
# Processing Record 13 of Set 15 | beian
# Processing Record 14 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 15 of Set 15 | borogontsy
# Processing Record 16 of Set 15 | uusikaupunki
# Processing Record 17 of Set 15 | sobolevo
# Processing Record 18 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 15 | lianran
# Processing Record 20 of Set 15 | kuldur
# Processing Record 21 of Set 15 | aykhal
# Processing Record 22 of Set 15 | margate
# Processing Record 23 of Set 15 | kaduna
# Processing Record 24 of Set 15 | miraflores
# Processing Record 25 of Set 15 | surt
# Processing Record 26 of Set 15 | spirit river
# Processing Record 27 of Set 15 | kiunga
# Processing Record 28 of Set 15 | koshki
# Processing Record 29 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 30 of Set 15 | dalhousie
# Processing Record 31 of Set 15 | abiy adi
# City not found. Skipping...
# Processing Record 32 of Set 15 | great falls
# Processing Record 33 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 15 | pizarro
# Processing Record 35 of Set 15 | san lorenzo
# Processing Record 36 of Set 15 | hermosillo
# Processing Record 37 of Set 15 | xuddur
# Processing Record 38 of Set 15 | touros
# Processing Record 39 of Set 15 | belogorsk
# Processing Record 40 of Set 15 | batemans bay
# Processing Record 41 of Set 15 | kapchorwa
# Processing Record 42 of Set 15 | katangli
# Processing Record 43 of Set 15 | wuwei
# Processing Record 44 of Set 15 | vao
# Processing Record 45 of Set 15 | sibolga
# Processing Record 46 of Set 15 | soe
# Processing Record 47 of Set 15 | diffa
# Processing Record 48 of Set 15 | zhezkazgan
# Processing Record 49 of Set 15 | lubango
# Processing Record 50 of Set 15 | kutum
# Processing Record 1 of Set 16 | iwanai
# Processing Record 2 of Set 16 | richards bay
# Processing Record 3 of Set 16 | nowogard
# Processing Record 4 of Set 16 | kiruna
# Processing Record 5 of Set 16 | tingi
# Processing Record 6 of Set 16 | salinas
# Processing Record 7 of Set 16 | port augusta
# Processing Record 8 of Set 16 | santa cruz
# Processing Record 9 of Set 16 | higuey
# City not found. Skipping...
# Processing Record 10 of Set 16 | san rafael
# Processing Record 11 of Set 16 | maku
# Processing Record 12 of Set 16 | marawi
# Processing Record 13 of Set 16 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 16 | uttaradit
# Processing Record 15 of Set 16 | riaba
# City not found. Skipping...
# Processing Record 16 of Set 16 | lae
# Processing Record 17 of Set 16 | darhan
# Processing Record 18 of Set 16 | beloha
# Processing Record 19 of Set 16 | cockburn harbour
# City not found. Skipping...
# Processing Record 20 of Set 16 | verkhnevilyuysk
# Processing Record 21 of Set 16 | gorzow wielkopolski
# Processing Record 22 of Set 16 | tukrah
# Processing Record 23 of Set 16 | noyabrsk
# Processing Record 24 of Set 16 | bowen
# Processing Record 25 of Set 16 | culebra
# Processing Record 26 of Set 16 | fenoarivo
# Processing Record 27 of Set 16 | meridian
# Processing Record 28 of Set 16 | takanabe
# Processing Record 29 of Set 16 | opuwo
# Processing Record 30 of Set 16 | cam ranh
# Processing Record 31 of Set 16 | juneau
# Processing Record 32 of Set 16 | gat
#
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e243ad989f34> in <module>
#       1 # Convert the array of dictionaries to a Pandas DataFrame.
# ----> 2 city_data_df = pd.DataFrame(city_data)
#       3 city_data_df.count()
#
# NameError: name 'pd' is not defined

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
#city_data_df.to_csv(output_data_file, index_label="City_ID")
